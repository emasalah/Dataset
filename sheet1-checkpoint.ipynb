# %%
import pandas as pd
data=pd.read_csv("Wuzzuf_Jobs.csv")
data.describe()
data
# Out:
#                                                Title  \
# 0                             Customer Service Agent
# 1                                  Marketing Manager
# 2                  Medical Representative Heliopolis
# 3                          Order Handling Specialist
# 4                                        Storekeeper
# ...                                              ...
# 4375      Corporate Sales Executive - Hotel Supplies
# 4376     Logistics Operations & Warehouse Supervisor
# 4377  English Teacher ( Second Language ) / Lower...
# 4378                         Project Manager - Cairo
# 4379                English Teacher / Primary Stages
#
#                                    Company     Location       Type  \
# 0                         Johnson Controls    New Cairo  Full Time
# 1                    SYE English Community        Dokki  Full Time
# 2                          So Value Pharma        Cairo  Full Time
# ...

# %%
x=data['Company'].value_counts()
import matplotlib.pyplot as plt
plt.pie(x)
plt.show()
x
# Out:
# Confidential           590
# Mishkat Nour            39
# Expand Cart             35
# EGIC                    34
# Aqarmap.com             25
#                       ...
# smartpace solutions      1
# LARIBA Chocolate         1
# Bakeland Egypt           1
# Blue Nile                1
# Egypt Otsuka             1
# Name: Company, Length: 1534, dtype: int64

# %%
data.sort_values("Title", inplace = True)

# dropping ALL duplicate values
data.drop_duplicates(subset ="Title",keep = "first", inplace = True)


# displaying data
data
# Out:
#                                                  Title           Company  \
# 3410                   .NET Angular Software Developer             Xceed
# 2859                       .NET Back-End Web Developer      Confidential
# 1717                                    .NET Developer  Beta Electronics
# 2862              .NET Developer (Desktop Application)      Confidential
# 3693                       .NET Developer - Internship   IKEN Technology
# ...                                                ...               ...
# 51                                  فنى صيانة ميكانيكا        EL SHIDEED
# 2481        مدير تنفيذ - Operations Director (Civil...              Agec
# 2561  مراجع لغة عربية - Arabic Proofreader (Hindawi...             Nagwa
# 673                             مسؤول إدارة المستفيدين      Mishkat Nour
# 495                            مندوب تحصيل - Collector           BituNil
#
#          Location        Type        Level         YearsExp Country  \
# ...

# %%
p=data['Title'].value_counts()
p
# Out:
# Area Sales Manager (Background Cosmetics)         1
# Sales Support                                     1
# Corporate Sales Executive - Hotel Supplies        1
# Full Stack Developer (Internship)                 1
# Senior BOQ & Specification Engineer               1
#                                                  ..
# Sector Sales Manager - Luxor                      1
# Warehouse Manager - Mit Ghamr (Pharmacist)        1
# Purchasing Specialist - Constructions             1
# HR Personnel Assistant (Clerk)                    1
# Purchasing Specialist (Automotive Spare Parts)    1
# Name: Title, Length: 2965, dtype: int64

# %%
data = {' Xceed':' .NET Angular Software Developer	', 'Beta Electronics':"NET Developer", 'Confidential':'NET Back-End Web Developer',
		'EL SHIDEED':'فنى صيانة ميكانيكا'}
Company = list(data.keys())
Title= list(data.values())


# creating the bar plot
plt.bar(Company,Title , color ='yellow', width = 0.4)


plt.xlabel("Company")
plt.ylabel("Title")
plt.title("the different Title of company")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
l=data['Location'].value_counts()
print(l)
# Out:
#  Cairo             369
#  Maadi             368
#  New Cairo         340
#  Nasr City         274
#  6th of October    216
#                   ...
#  Bab Sharq           1
#  Marg                1
#  Surabaya            1
#  Damanhour           1
#  New Menia           1
# Name: Location, Length: 153, dtype: int64

# %%
data = {' Xceed':'Maadi ', 'Beta Electronics':"Dokki", 'Confidential':'Cairo','EL SHIDEED':'Obour City'}

Company = list(data.keys())
Location= list(data.values())


# creating the bar plot
plt.bar(Company,Location , color ='red',width = 0.4)


plt.xlabel("Company")
plt.ylabel("Location")
plt.title("the different Location of company")
plt.show()

# %%
Skills=data['Skills'].value_counts()
data.sort_values("Skills", inplace = True)

# to convert skills column into list 
skills=data.Skills.tolist()
for skill in skills :
    print(skill)
    print ()
# Out:
# .NET Core, Bootstrap, javaScript, Software Development, HTML, CSS, Information Technology (IT), IT/Software Development
#
# .NET Development, Computer Science, Computer Engineering, Information Technology (IT), C#, MVC, ASP.NET, Angular, Typescript, HTML5
#
# .NET, Angular, Information Technology (IT), Software Development, CSS, Computer Science, javaScript, Front-End, MongoDB, MySQL
#
# .NET, MVC, C#, TFS, Git, Software Development, Information Technology (IT), Computer Science, IT/Software Development
#
# .NET, javaScript, Computer Science, Information Technology (IT), PHP, Angular, HTML, CSS, SQL, React, XML
#
# 0-1 Yrs of Exp, 10 Vacancies, Pharmacy, Science, Beauty, Cosmetics, Gulf Area, R&D/Science, Customer Service/Support
#
# 0-2 Yrs of Exp, 2 Vacancies, Languages, Linguistics, Training, Translation, Instructor, Education, IQP, Teaching
#
# 0-2 Yrs of Exp, 2 Vacancies, Languages, Linguistics, Training, Translation, Instructor, Education, IQP, Teaching
#
# ...
